# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.7-py3-none-any.whl (55 kB)
# Requirement already satisfied: urllib3 in c:\programdata\anaconda3\lib\site-packages (from chembl_webresource_client) (1.26.7)
# Collecting requests-cache~=0.7.0
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Collecting easydict
#   Downloading easydict-1.9.tar.gz (6.4 kB)
# Requirement already satisfied: requests>=2.18.4 in c:\programdata\anaconda3\lib\site-packages (from chembl_webresource_client) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: attrs<22.0,>=21.2 in c:\programdata\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in c:\programdata\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: pyyaml>=5.4 in c:\programdata\anaconda3\lib\site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py): started
#   Building wheel for easydict (setup.py): finished with status 'done'
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6360 sha256=ae57562f301a8b46e8dabf1cfdd442ceb76ae6cce70684d53c29a7f947c2acdb
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\b2\1c\36\fd8efc3fa029b1445d869f359ec13e8fbce7fc9e81505bca66
# Successfully built easydict
# Installing collected packages: url-normalize, requests-cache, easydict, chembl-webresource-client
# Successfully installed chembl-webresource-client-0.10.7 easydict-1.9 requests-cache-0.7.5 url-normalize-1.4.3

# %%
## IMPORTO LIBRERIAS

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# busco la base de datos de las proteinas de chmbl
target = new_client.target# +-min 10
target_query = target.search('Mycobacterium tuberculosis')#pongo la palabra clave que va a buscar de chmbl
targets = pd.DataFrame.from_dict(target_query)
targets#los targets o objetivos se refieren a las proteinas especificas o al organismo objetivo sobre el que actuara el farmaco,por lo que biologicamente estos compuestos entraran en contacto con la proteina o organismo e inducir una actividad moduladora hacia el, podria ser, activar la proteina o organismo, o inhibirlo
#https://www.ebi.ac.uk/chembl/g/#search_results/assays/query=Mycobacterium%20tuberculosis## base de datos extraida
# Out:
#     cross_references                          organism  \
# 0                 []        Mycobacterium tuberculosis
# 1                 []  Mycobacterium tuberculosis H37Rv
# 2                 []  Mycobacterium tuberculosis H37Ra
# 3                 []                     Mycobacterium
# 4                 []        Mycobacterium tuberculosis
# ..               ...                               ...
# 115               []        Mycobacterium tuberculosis
# 116               []        Mycobacterium tuberculosis
# 117               []        Mycobacterium tuberculosis
# 118               []        Mycobacterium tuberculosis
# 119               []        Mycobacterium tuberculosis
#
#                                              pref_name  score  \
# 0                           Mycobacterium tuberculosis   27.0
# 1                     Mycobacterium tuberculosis H37Rv   24.0
# 2                     Mycobacterium tuberculosis H37Ra   24.0
# 3                                        Mycobacterium   13.0
# 4            PYRAZINAMIDASE/NICOTINAMIDAS PNCA (PZase)   13.0
# ..                                                 ...    ...
# 115  Ribonucleoside-diphosphate reductase subunit a...    7.0
# 116                                       70S ribosome    7.0
# 117                                       ATP synthase    7.0
# 118                              Thioredoxin reductase    7.0
# 119  ATP-dependent Clp protease ATP-binding subunit...    7.0
#
#      species_group_flag target_chembl_id  \
# 0                 False        CHEMBL360
# 1                 False    CHEMBL2111188
# 2                 False    CHEMBL2366634
# 3                  True     CHEMBL614981
# 4                 False    CHEMBL1697663
# ..                  ...              ...
# 115               False    CHEMBL2346487
# 116               False    CHEMBL2363965
# 117               False    CHEMBL2364166
# 118               False    CHEMBL2390811
# 119               False    CHEMBL4630874
#
#                                      target_components  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4    [{'accession': 'Q50575', 'component_descriptio...
# ..                                                 ...
# 115  [{'accession': 'P9WH75', 'component_descriptio...
# 116  [{'accession': 'P9WHE1', 'component_descriptio...
# 117  [{'accession': 'P9WPU9', 'component_descriptio...
# 118  [{'accession': 'P9WHH1', 'component_descriptio...
# 119  [{'accession': 'P9WPC9', 'component_descriptio...
#
#                       target_type  tax_id
# 0                        ORGANISM    1773
# 1                        ORGANISM   83332
# 2                        ORGANISM  419947
# 3                        ORGANISM    1763
# 4                  SINGLE PROTEIN    1773
# ..                            ...     ...
# 115                SINGLE PROTEIN    1773
# 116  PROTEIN NUCLEIC-ACID COMPLEX    1773
# 117               PROTEIN COMPLEX    1773
# 118                SINGLE PROTEIN    1773
# 119                SINGLE PROTEIN    1773
#
# [120 rows x 9 columns]

# %%
#119 posibles objetivos
# vamos a usar una proteina sola o single protein

# %%
# siguiente voy a seleccionar y recuperar datos de bioactividad para la Mycobacterium tuberculosis de la proteina
#

# %%
selected_target = targets.target_chembl_id[115]#pongo aqui la ubicacion de la entrada que deseo trabajar
print(selected_target)
# Out:
# CHEMBL2346487

# %%
# ahora defino una variable llamada actividad y uso new_client.activity y defino una variable llamada RES y le asigno el bloque de codigo con la ubicacion de entrada de mi proteina objetivo

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="Kd")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None     12723283                  []   CHEMBL2352781
# 1             None     12723284                  []   CHEMBL2352781
# 2             None     12723285                  []   CHEMBL2352781
# 3             None     12723286                  []   CHEMBL2352781
# 4             None     12723287                  []   CHEMBL2352781
# 5             None     12723288                  []   CHEMBL2352781
# 6             None     12723289                  []   CHEMBL2352781
#
#                                    assay_description assay_type  \
# 0  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 1  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 2  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 3  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 4  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 5  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 6  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000034  BAO_0000357
# 1                    None                   None  BAO_0000034  BAO_0000357
# 2                    None                   None  BAO_0000034  BAO_0000357
# 3                    None                   None  BAO_0000034  BAO_0000357
# 4                    None                   None  BAO_0000034  BAO_0000357
# 5                    None                   None  BAO_0000034  BAO_0000357
# 6                    None                   None  BAO_0000034  BAO_0000357
#
#    ...             target_organism  \
# 0  ...  Mycobacterium tuberculosis
# 1  ...  Mycobacterium tuberculosis
# 2  ...  Mycobacterium tuberculosis
# 3  ...  Mycobacterium tuberculosis
# 4  ...  Mycobacterium tuberculosis
# 5  ...  Mycobacterium tuberculosis
# 6  ...  Mycobacterium tuberculosis
#
#                                     target_pref_name target_tax_id text_value  \
# 0  Ribonucleoside-diphosphate reductase subunit a...          1773       None
# 1  Ribonucleoside-diphosphate reductase subunit a...          1773       None
# 2  Ribonucleoside-diphosphate reductase subunit a...          1773       None
# 3  Ribonucleoside-diphosphate reductase subunit a...          1773       None
# 4  Ribonucleoside-diphosphate reductase subunit a...          1773       None
# 5  Ribonucleoside-diphosphate reductase subunit a...          1773       None
# 6  Ribonucleoside-diphosphate reductase subunit a...          1773       None
#
#    toid type  units    uo_units upper_value  value
# 0  None   Kd     uM  UO_0000065        None   26.0
# 1  None   Kd     uM  UO_0000065        None    8.1
# 2  None   Kd     uM  UO_0000065        None    1.6
# 3  None   Kd     uM  UO_0000065        None  150.0
# 4  None   Kd     uM  UO_0000065        None   27.0
# 5  None   Kd     uM  UO_0000065        None   81.0
# 6  None   Kd     uM  UO_0000065        None    8.3
#
# [7 rows x 45 columns]

# %%
## son de tipo crecimiento celular, si fuera de otro tipos puede haber una combinacion de unidades de bioactividad, entonces un solo tipo  hara que nuestro conjunto de datos sea uniforme 
### el valor es la potencia de el farmaco, cuanto menor sea en numero, mejor sera la potencia del farmaco y todo lo contrario si el numero es muy alto. esto significa que la concentracion inhibitoria al 50% tiene una concentracion baja, lo que significa que para obtener el 50% de la inhibicion de una proteina objetivo, es necesaria una concentracion mas baja
# en sintesis ESE NUMERO SIGNIFICA LA CONCENTRACION DEL FARMACO PARA SER EFECTIVO, por lo tanto entre menor concetracion mas efectividad del farmaco
## un numero alto puede ser hasta miles pero en nuestro caso hay valores bajos por lo tanto son una buena opcion

# %%
### Finalmente, guardaremos los datos de bioactividad resultantes en un archivo CSV bioactividad_datos.csv.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %%
# %pwd ##miro el directorio donde estan mis archivos
# Out:
# 'C:\\Users\\LENOVO\\Music\\Untitled Folder'

# %%
### paso opcional esta celda elimina a todos los medicamentos que no tienen valor o value por lo tanto no sirven 
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
len(df2.canonical_smiles.unique()) #cuenta cuantos medicamentos me quedaron despues de eliminar con el paso anterior en este caso no se elimino ninguno
# Out:
# 7

# %%
#Los datos de bioactividad que son de tipo Kd. Los compuestos que tengan valores inferiores a 10 nM se considerarán activos mientras que los superiores a 100 nM se considerarán inactivos. En cuanto a aquellos valores entre 20 y 30 nM se denominarán intermedios.

# %%
df4 = pd.read_csv('bioactivity_data_raw.csv') #leo el archivo .csv generado

# %%
bioactivity_threshold = []
for i in df4.value:
  if float(i) >= 80:
    bioactivity_threshold.append("MENOS eficiente")
  elif float(i) <= 10:
    bioactivity_threshold.append("MAS eficiente")
  else:
    bioactivity_threshold.append("intermedio")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               NaN     12723283                  []   CHEMBL2352781
# 1               NaN     12723284                  []   CHEMBL2352781
# 2               NaN     12723285                  []   CHEMBL2352781
# 3               NaN     12723286                  []   CHEMBL2352781
# 4               NaN     12723287                  []   CHEMBL2352781
# 5               NaN     12723288                  []   CHEMBL2352781
# 6               NaN     12723289                  []   CHEMBL2352781
#
#                                    assay_description assay_type  \
# 0  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 1  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 2  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 3  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 4  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 5  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
# 6  Displacement of Dansyl-Gly-Ser-Gly-Glu-Asp-Asp...          B
#
#    assay_variant_accession  assay_variant_mutation bao_endpoint   bao_format  \
# 0                      NaN                     NaN  BAO_0000034  BAO_0000357
# 1                      NaN                     NaN  BAO_0000034  BAO_0000357
# 2                      NaN                     NaN  BAO_0000034  BAO_0000357
# 3                      NaN                     NaN  BAO_0000034  BAO_0000357
# 4                      NaN                     NaN  BAO_0000034  BAO_0000357
# 5                      NaN                     NaN  BAO_0000034  BAO_0000357
# 6                      NaN                     NaN  BAO_0000034  BAO_0000357
#
#    ...                                   target_pref_name target_tax_id  \
# 0  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
# 1  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
# 2  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
# 3  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
# 4  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
# 5  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
# 6  ...  Ribonucleoside-diphosphate reductase subunit a...          1773
#
#   text_value toid type units    uo_units upper_value  value            class
# 0        NaN  NaN   Kd    uM  UO_0000065         NaN   26.0       intermedio
# 1        NaN  NaN   Kd    uM  UO_0000065         NaN    8.1    MAS eficiente
# 2        NaN  NaN   Kd    uM  UO_0000065         NaN    1.6    MAS eficiente
# 3        NaN  NaN   Kd    uM  UO_0000065         NaN  150.0  MENOS eficiente
# 4        NaN  NaN   Kd    uM  UO_0000065         NaN   27.0       intermedio
# 5        NaN  NaN   Kd    uM  UO_0000065         NaN   81.0  MENOS eficiente
# 6        NaN  NaN   Kd    uM  UO_0000065         NaN    8.3    MAS eficiente
#
# [7 rows x 46 columns]

# %%
#chembl_id es un conjunto de datos que esta compuesto por muchos compuestos y un compuesto es un farmaco, osea una molecula que es una estructura quimica que produce una actividad moduladora que ejerce un efecto sobre la proteina objetivo, que produce efectos biologicos en el cuerpo, por lo tanto cura los sintomas
# cada compuesto se describe mediante una id_chembl, cada fila representa un compuesto y puede ser que varias filas contengan la misma id y si es que es el caso, las debemos eliminar para evitar redundancias

# %%
df2.molecule_chembl_id
# Out:
# 0    CHEMBL2348060
# 1    CHEMBL2348059
# 2    CHEMBL2348058
# 3    CHEMBL2348057
# 4    CHEMBL2348056
# 5    CHEMBL2348055
# 6    CHEMBL2348054
# Name: molecule_chembl_id, dtype: object

# %%
#ninguno se repite por lo tanto cada fila es un compuesto diferente

# %%
df5.to_csv('bioactivity_data_depurated.csv', index=False)##guardo los mismos compuestos con las etiquetas de eficiencia en un archivo .csv
